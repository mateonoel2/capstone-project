# %% [markdown]
# # Bank Statement Extraction - Exploration
#
# This notebook demonstrates how to use the extraction framework.

# %%
import sys
from pathlib import Path

import pandas as pd

project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

from dotenv import load_dotenv

load_dotenv()

# %% [markdown]
# ## Example Usage
#
# See PROJECT_README.md for detailed documentation.
